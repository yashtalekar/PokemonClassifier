# %% [markdown]
# <a href="https://colab.research.google.com/github/yashtalekar/PokemonClassifier/blob/main/PokemonImageLoader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is to mount Google Drive to get data.
from google.colab import drive
drive.mount('/content/gdrive')

import pathlib
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
data = pathlib.Path('/content/gdrive/My Drive/PokemonData/pokemon_images') 
pok_images = list(data.glob('*[0-9].png'))
pok_images = list(data.glob('[0-9].png')) + pok_images 
count = len(pok_images)
PIL.Image.open(str(pok_images[0]))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7F9CC184A590>
